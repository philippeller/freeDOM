# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
#os.environ["CUDA_VISIBLE_DEVICES"]=""
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %load_ext autoreload
# %autoreload 2

from i3cols_dataloader import load_data
from sklearn.model_selection import train_test_split

import gc

from transformations import trafo_indep, trafo_q

# %load_ext line_profiler

# %%
plt.rcParams['figure.figsize'] = [12., 8.]
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14 
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['legend.fontsize'] = 14

# %%
tf.test.is_gpu_available()
# Out:
# True

# %% [markdown]
# # Prepare data

# %%
single_hits, repeated_params, total_charge, params, labels = load_data()

# %%
single_hits_train, single_hits_test, repeated_params_train, repeated_params_test = train_test_split(single_hits,repeated_params, test_size=0.01, random_state=42)
total_charge_train, total_charge_test, params_train, params_test = train_test_split(total_charge, params, test_size=0.01, random_state=42)

# %% [markdown]
# # Create NNs

# %%
activation='relu'

hits_input = tf.keras.Input(shape=(5,))
params_input = tf.keras.Input(shape=(len(labels),))
t = trafo_indep(labels=labels)

h = t(hits_input, params_input)
h = tf.keras.layers.Dense(32, activation="relu")(h)
h = tf.keras.layers.Dense(64, activation="relu")(h)
h = tf.keras.layers.Dropout(0.001)(h)
h = tf.keras.layers.Dense(128, activation="relu")(h)
h = tf.keras.layers.Dropout(0.001)(h)
h = tf.keras.layers.Dense(256, activation="relu")(h)
h = tf.keras.layers.Dropout(0.001)(h)
h = tf.keras.layers.Dense(128, activation="relu")(h)
h = tf.keras.layers.Dropout(0.001)(h)
h = tf.keras.layers.Dense(64, activation="relu")(h)
h = tf.keras.layers.Dense(32, activation="relu")(h)
outputs = tf.keras.layers.Dense(1, activation='sigmoid')(h)

hit_net = tf.keras.Model(inputs=[hits_input, params_input], outputs=outputs)
hit_net.summary()

loss_history = []
val_loss_history = []
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 5)]          0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# trafo_indep (trafo_indep)       (None, 15)           0           input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           512         trafo_indep[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           2112        dense[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          8320        dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          33024       dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          32896       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           8256        dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 32)           2080        dense_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            33          dense_6[0][0]
# ==================================================================================================
# Total params: 87,233
# Trainable params: 87,233
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
activation='relu'


charge_input = tf.keras.Input(shape=(1,))
params_input = tf.keras.Input(shape=(len(labels),))
t = trafo_q(labels=labels)

h = t(charge_input, params_input)
h = tf.keras.layers.Dense(32, activation="relu")(h)
h = tf.keras.layers.Dense(64, activation="relu")(h)
h = tf.keras.layers.Dropout(0.001)(h)
h = tf.keras.layers.Dense(128, activation="relu")(h)
h = tf.keras.layers.Dropout(0.001)(h)
h = tf.keras.layers.Dense(256, activation="relu")(h)
h = tf.keras.layers.Dropout(0.001)(h)
h = tf.keras.layers.Dense(128, activation="relu")(h)
h = tf.keras.layers.Dropout(0.001)(h)
h = tf.keras.layers.Dense(64, activation="relu")(h)
h = tf.keras.layers.Dense(32, activation="relu")(h)
outputs = tf.keras.layers.Dense(1, activation='sigmoid')(h)

charge_net = tf.keras.Model(inputs=[charge_input, params_input], outputs=outputs)
charge_net.summary()

loss_history_q = []
val_loss_history_q = []
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# trafo_q (trafo_q)               (None, 9)            0           input_3[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 32)           320         trafo_q[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 64)           2112        dense_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 64)           0           dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 128)          8320        dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 128)          0           dense_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 256)          33024       dropout_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 256)          0           dense_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 128)          32896       dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 128)          0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 64)           8256        dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 32)           2080        dense_13[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1)            33          dense_14[0][0]
# ==================================================================================================
# Total params: 87,041
# Trainable params: 87,041
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(0.00001)
hit_net.compile(loss='binary_crossentropy', optimizer=optimizer)

# %%
optimizer = tf.keras.optimizers.Adam(0.000003)
charge_net.compile(loss='binary_crossentropy', optimizer=optimizer)

# %% [markdown]
# create tf datasets

# %%
N = single_hits_train.shape[0]

# %%
N

# %%
d_single_hits_train = tf.data.Dataset.from_tensor_slices(single_hits_train)
d_repeated_params_train = tf.data.Dataset.from_tensor_slices(repeated_params_train)

d_true_labels_train = tf.data.Dataset.from_tensor_slices(np.ones(N, dtype=np.float32).reshape(N, -1))
d_false_labels_train = tf.data.Dataset.from_tensor_slices(np.zeros(N, dtype=np.float32).reshape(N, -1))

d_hits_train = tf.data.Dataset.concatenate(d_single_hits_train, d_single_hits_train)
d_params_train = tf.data.Dataset.concatenate(d_repeated_params_train, d_repeated_params_train.shuffle(N))
d_outputs_train = tf.data.Dataset.concatenate(d_true_labels_train, d_false_labels_train)

d_inputs_train = tf.data.Dataset.zip((d_hits_train, d_params_train))

dataset_train = tf.data.Dataset.zip((d_inputs_train, d_outputs_train))

# %%
# def shuffle(hits, params, each_row=True):
#     shuffled_hits = np.vstack([hits, hits])
#     if each_row:
#         shuf = np.empty_like(params)
#         for col in range(params.shape[1]):
#             indices = np.random.permutation(np.arange(params.shape[0]))
#             shuf[:, col] = params[indices, col]
#     else:
#         shuf = np.random.permutation(params)
#     shuffled_params = np.vstack([params, shuf])
#     target = np.concatenate([np.ones(hits.shape[0]), np.zeros(hits.shape[0])])
#     return shuffled_hits, shuffled_params, target

# %%
for d in dataset_train:
    print(d[0])
    break
# Out:
# (<tf.Tensor: id=148405, shape=(5,), dtype=float32, numpy=
# array([ 1.2497e+02, -1.3125e+02, -4.2547e+02,  1.1203e+04,  2.2500e-01],
#       dtype=float32)>, <tf.Tensor: id=148406, shape=(8,), dtype=float32, numpy=
# array([ 1.7429903e+02, -1.1469879e+02, -4.7699335e+02,  9.5026748e+03,
#         6.2565947e+00,  2.7268991e-01,  1.2920137e+02,  1.7558663e+00],
#       dtype=float32)>)

# %%
gc.collect()
# Out:
# 294

# %%
dt = dataset_train.shuffle(2*N).batch(1024)

# %%
pf = dt.prefetch(2).cache()

# %%
for i in range(40):
    print(i)
    h = hit_net.fit(pf, 
                epochs=30,
                verbose=2,
                )
    hit_net.save('models/tfdata_hitnet_%i.h5'%(i*30))
# Out:
# 0
# Epoch 1/30
# 20997/20997 - 55s - loss: 0.3242
# Epoch 2/30
# 20997/20997 - 55s - loss: 0.3203
# Epoch 3/30
# 20997/20997 - 55s - loss: 0.3170
# Epoch 4/30
# 20997/20997 - 55s - loss: 0.3141
# Epoch 5/30
# 20997/20997 - 55s - loss: 0.3116
# Epoch 6/30
# 20997/20997 - 55s - loss: 0.3094
# Epoch 7/30
# 20997/20997 - 55s - loss: 0.3075
# Epoch 8/30
# 20997/20997 - 55s - loss: 0.3058
# Epoch 9/30
# 20997/20997 - 55s - loss: 0.3043
# Epoch 10/30
# 20997/20997 - 55s - loss: 0.3030
# Epoch 11/30
# 20997/20997 - 55s - loss: 0.3019
# Epoch 12/30
# 20997/20997 - 55s - loss: 0.3008
# Epoch 13/30
# 20997/20997 - 55s - loss: 0.2999
# Epoch 14/30
# 20997/20997 - 55s - loss: 0.2990
# Epoch 15/30
# 20997/20997 - 54s - loss: 0.2982
# Epoch 16/30
# 20997/20997 - 55s - loss: 0.2975
# Epoch 17/30
# 20997/20997 - 55s - loss: 0.2969
# Epoch 18/30
# 20997/20997 - 55s - loss: 0.2963
# Epoch 19/30
# 20997/20997 - 55s - loss: 0.2957
# Epoch 5/30
# 20997/20997 - 55s - loss: 0.2862
# Epoch 6/30
# 20997/20997 - 54s - loss: 0.2860
# Epoch 7/30
# 20997/20997 - 55s - loss: 0.2859
# Epoch 8/30
# 20997/20997 - 54s - loss: 0.2858
# Epoch 9/30
# 20997/20997 - 54s - loss: 0.2857
# Epoch 10/30
# 20997/20997 - 55s - loss: 0.2856
# Epoch 11/30
# 20997/20997 - 54s - loss: 0.2855
# Epoch 12/30
# 20997/20997 - 55s - loss: 0.2854
# Epoch 13/30
# 20997/20997 - 54s - loss: 0.2854
# Epoch 14/30
# 20997/20997 - 55s - loss: 0.2853
# Epoch 15/30
# 20997/20997 - 55s - loss: 0.2852
# Epoch 16/30
# 20997/20997 - 54s - loss: 0.2851
# Epoch 17/30
# 20997/20997 - 55s - loss: 0.2850
# Epoch 18/30
# 20997/20997 - 56s - loss: 0.2849
# Epoch 19/30
# 20997/20997 - 56s - loss: 0.2848
# Epoch 20/30
# 20997/20997 - 56s - loss: 0.2848
# Epoch 21/30
# 20997/20997 - 56s - loss: 0.2847
# Epoch 22/30
# 20997/20997 - 56s - loss: 0.2846
# Epoch 23/30
# 20997/20997 - 55s - loss: 0.2846
# Epoch 24/30
# 20997/20997 - 56s - loss: 0.2845
# Epoch 25/30

# %%
hit_net.save('models/tfdata_hitnet.h5')

# %%
# %%time
for i in range(1):
    
    shuffled_hits_train, shuffled_params_train, outputs_train = shuffle(single_hits_train, repeated_params_train)
    shuffled_hits_test, shuffled_params_test, outputs_test = shuffle(single_hits_test, repeated_params_test)
    
    gc.collect()

    print('Epoch %i'%(len(loss_history)+1))
    
    hit_net.fit([shuffled_hits_train,
                 shuffled_params_train], 
                 outputs_train, 
                 batch_size=1024, 
                 epochs=1, 
                 validation_data=([shuffled_hits_test, 
                                   shuffled_params_test],
                                   outputs_test),
                 #callbacks=[my_history,],
                 verbose=2,
                )

    loss_history.append(hit_net.history.history['loss'])
    val_loss_history.append(hit_net.history.history['val_loss'])
    
    #if (i+1)%50 == 0:
    #    hit_net.save('models/new_hit_net%i.h5'%(i + 1 + 700))
# Out:
# Epoch 301
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 66s - loss: 0.2122 - val_loss: 0.2083
# Epoch 302
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 66s - loss: 0.2120 - val_loss: 0.2102
# Epoch 303
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 66s - loss: 0.2120 - val_loss: 0.2082
# Epoch 304
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 65s - loss: 0.2120 - val_loss: 0.2096
# Epoch 305
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 66s - loss: 0.2119 - val_loss: 0.2090
# Epoch 306
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 65s - loss: 0.2120 - val_loss: 0.2087
# Epoch 307
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 65s - loss: 0.2119 - val_loss: 0.2092
# Epoch 308
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 66s - loss: 0.2119 - val_loss: 0.2089
# Epoch 309
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 65s - loss: 0.2119 - val_loss: 0.2096
# Epoch 310
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 65s - loss: 0.2118 - val_loss: 0.2089
# Epoch 311
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 66s - loss: 0.2120 - val_loss: 0.2088
# Epoch 312
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 86s - loss: 0.2118 - val_loss: 0.2088
# Epoch 313
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 66s - loss: 0.2118 - val_loss: 0.2098
# Epoch 314
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 66s - loss: 0.2117 - val_loss: 0.2097
# Epoch 315
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 65s - loss: 0.2117 - val_loss: 0.2101
# Epoch 316
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 66s - loss: 0.
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 66s - loss: 0.2075 - val_loss: 0.2033
# Epoch 560
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 64s - loss: 0.2076 - val_loss: 0.2039
# Epoch 561
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 65s - loss: 0.2076 - val_loss: 0.2024
# Epoch 562
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 64s - loss: 0.2075 - val_loss: 0.2029
# Epoch 563
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 65s - loss: 0.2075 - val_loss: 0.2057
# Epoch 564
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 67s - loss: 0.2075 - val_loss: 0.2036
# Epoch 565
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 66s - loss: 0.2074 - val_loss: 0.2035
# Epoch 566
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 66s - loss: 0.2076 - val_loss: 0.2053
# Epoch 567
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 62s - loss: 0.2074 - val_loss: 0.2040
# Epoch 568
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 65s - loss: 0.2074 - val_loss: 0.2039
# Epoch 569
# Train on 21500230 samples, validate on 217176 samples
# 21500230/21500230 - 61s - loss: 0.2074 - val_loss: 0.2022
# Epoch 570
# Train on 21500230 samples, validate on 217176 samples

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,8))
x = np.arange(1, len(loss_history)+1)
ax.plot(x, np.concatenate(loss_history), label='train')
ax.plot(x, np.concatenate(val_loss_history), label='test')
ax.set_yscale('log')
#ax.set_xscale('log')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.legend()
#plt.savefig('train.png')

# %%
hit_net.save('models/new_hit_net500.h5')

# %%
hit_net = tf.keras.models.load_model('models/new_hit_net350.h5', custom_objects={'trafo_indep':trafo_indep})

# %%
for i in range(10000):
    
    shuffled_q_charges_train, shuffled_q_params_train, outputs_q_train = shuffle(total_charge_train, params_train)
    shuffled_q_charges_test, shuffled_q_params_test, outputs_q_test = shuffle(total_charge_test, params_test)
    
    gc.collect()

    print('Epoch %i'%(len(loss_history_q)+1))
    
    charge_net.fit([shuffled_q_charges_train.flatten()[:, np.newaxis],
                    shuffled_q_params_train], 
                    outputs_q_train, 
                    batch_size=128, 
                    epochs=1, 
                    validation_data=([shuffled_q_charges_test.flatten()[:, np.newaxis], 
                                      shuffled_q_params_test], 
                                      outputs_q_test),
                   # callbacks=[my_history_q,],
                   verbose=2,
                  ) 

    loss_history_q.append(charge_net.history.history['loss'])
    val_loss_history_q.append(charge_net.history.history['val_loss'])
    
    if (i+1)%50 == 0:
        hit_net.save('models/new_charge_net_longtrain_%i.h5'%(i + 1))
   


fig, ax = plt.subplots(1, 1, figsize=(12,8))
x = np.arange(1, len(loss_history_q)+1)
ax.plot(x, np.concatenate(loss_history_q), label='train')
ax.plot(x, np.concatenate(val_loss_history_q), label='test')
ax.set_yscale('log')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.legend()
# Out:
# Epoch 1
# Train on 851212 samples, validate on 8600 samples
# 851212/851212 - 21s - loss: 0.3829 - val_loss: 0.3787
# Epoch 2
# Train on 851212 samples, validate on 8600 samples
# 851212/851212 - 19s - loss: 0.3842 - val_loss: 0.3839
# Epoch 3
# Train on 851212 samples, validate on 8600 samples
# 851212/851212 - 19s - loss: 0.3838 - val_loss: 0.3850
# Epoch 4
# Train on 851212 samples, validate on 8600 samples

# %%
charge_net.save('models/new_charge_net_long.h5')

# %%
charge_net = tf.keras.models.load_model('models/new_charge_net.h5', custom_objects={'trafo_q':trafo_q})
